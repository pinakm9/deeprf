# %%
import os, sys 
from pathlib import Path
from os.path import dirname, realpath
script_dir = Path(dirname(realpath('.')))
module_dir = str(script_dir)
sys.path.insert(0, module_dir + '/modules')
import numpy as np
import utility as ut
import matplotlib.pyplot as plt
import pandas as pd
import warnings
from scipy import stats
import seaborn as sns
import sample as sm
import chain as arch 
import torch
# warnings.filterwarnings('ignore')

# %%
Uo = np.load('../data/L63-trajectories/train.npy')
Vo = np.load('../data/L63-trajectories/test.npy')
L0, L1 = 0.4, 3.5
D, D_r, B = 3, 300, 2
beta = 4e-5
m = 500

# %%
B = 1
rf1 = arch.DeepRF(D_r, B, L0, L1, Uo, beta, name='test', save_folder='../data')
rf1.init()
tau1 = rf1.compute_tau_f_(Vo[0:m])
# Out:
# Time taken by sample is 0.0054 seconds
# Time taken by compute_tau_f_ is 9.6693 seconds

# %%
B = 2
rf2 = arch.DeepRF(D_r, B, L0, L1, Uo, beta, name='test', save_folder='../data')
rf2.init()
tau2 = rf2.compute_tau_f_(Vo[0:m])
# Out:
# Time taken by sample is 0.0054 seconds
# Time taken by sample is 0.0056 seconds
# Time taken by compute_tau_f_ is 17.6815 seconds

# %%
B = 3
rf3 = arch.DeepRF(D_r, B, L0, L1, Uo, beta, name='test', save_folder='../data')
rf3.init()
tau3 = rf3.compute_tau_f_(Vo[0:m])
# Out:
# Time taken by sample is 0.0053 seconds
# Time taken by sample is 0.0055 seconds
# Time taken by sample is 0.0056 seconds
# Time taken by compute_tau_f_ is 25.2688 seconds

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
sns.histplot(tau1[1], ax=ax, label=f'depth=1, mean={tau1[1].mean():.2f}', alpha=0.7, stat='probability')
sns.histplot(tau2[1], ax=ax, label=f'depth=2, mean={tau2[1].mean():.2f}', alpha=0.7, stat='probability')
sns.histplot(tau3[1], ax=ax, label=f'depth=3, mean={tau3[1].mean():.2f}', alpha=0.7, stat='probability')
ax.legend()
ax.set_title(fr'$\tau_f$, architecture=chain, $D_r$={D_r}')
plt.savefig('../data/plots/chain-tau_f.png', bbox_inches='tight', dpi=300)

# %%
a = np.random.normal(size=(3, 4))
s = np.array([-1., 1., -1.])

# %%
a, a*s[:, np.newaxis]
# Out:
# (array([[ 0.64849279, -0.36828351,  0.46734419, -0.47140615],
#         [ 0.0862222 , -1.19868125,  0.28352618, -1.18210626],
#         [ 0.95908621, -0.55631589, -2.15862643,  0.8695171 ]]),
#  array([[-0.64849279,  0.36828351, -0.46734419,  0.47140615],
#         [ 0.0862222 , -1.19868125,  0.28352618, -1.18210626],
#         [-0.95908621,  0.55631589,  2.15862643, -0.8695171 ]]))

# %%
np.sign(a[:, -1])
# Out:
# array([-1., -1.,  1.])
