# %%
import os, sys 
from pathlib import Path
from os.path import dirname, realpath
script_dir = Path(dirname(realpath('.')))
module_dir = str(script_dir)
sys.path.insert(0, module_dir + '/modules')
import numpy as np
import utility as ut
import matplotlib.pyplot as plt
import pandas as pd
import warnings
from scipy import stats
import seaborn as sns
import chain as arch 
import torch
# warnings.filterwarnings('ignore')

# %%
Uo = np.load('../data/L63-trajectories/train.npy')[:, :20000]
Vo = np.load('../data/L63-trajectories/test.npy')
L0, L1 = 0.4, 3.5
D, D_r, B = 3, 256, 2
beta = 4e-5
m = 500

# %%
B = 1
rf1 = arch.DeepRF(D_r, B, L0, L1, Uo, beta, name='rf', save_folder=f'../data/chain/depth-{B}')
rf1.init()
tau1 = rf1.compute_tau_f_(Vo[0:m])
# Out:
# Time taken by sample is 0.0047 seconds
# Time taken by compute_tau_f_ is 9.6367 seconds

# %%
B = 2
rf2 = arch.DeepRF(D_r, B, L0, L1, Uo, beta, name='rf', save_folder=f'../data/chain/depth-{B}')
rf2.init()
tau2 = rf2.compute_tau_f_(Vo[0:m])
# Out:
# Time taken by sample is 0.0048 seconds
# Time taken by sample is 0.0111 seconds
# Time taken by compute_tau_f_ is 18.4153 seconds

# %%
activation = {}
def get_activation(name):
    def hook(model, input, output):
        activation[name] = output.detach()
    return hook

B = 3
rf3 = arch.DeepRF(D_r, B, L0, L1, Uo, beta, name='rf', save_folder=f'../data/chain/depth-{B}')
rf3.init()
tau3 = rf3.compute_tau_f_(Vo[0:m])
# Out:
# Time taken by sample is 0.0050 seconds
# Time taken by sample is 0.0187 seconds
# Time taken by sample is 0.0049 seconds
# Time taken by compute_tau_f_ is 26.7597 seconds

# %%
B = 10
rf10 = arch.DeepRF(D_r, B, L0, L1, Uo, beta, name='rf', save_folder=f'../data/chain/depth-{B}')
rf10.init()
tau10 = rf10.compute_tau_f_(Vo[0:m])
# Out:
# Time taken by sample is 0.0048 seconds
# Time taken by sample is 0.0125 seconds
# Time taken by sample is 0.0048 seconds
# Time taken by sample is 0.0210 seconds
# Time taken by sample is 0.0074 seconds
# Time taken by sample is 0.0059 seconds
# Time taken by sample is 0.0049 seconds
# Time taken by sample is 0.0059 seconds
# Time taken by sample is 0.0115 seconds
# Time taken by sample is 0.0157 seconds
# Time taken by compute_tau_f_ is 84.2787 seconds

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
sns.histplot(tau1[1], ax=ax, label=r'depth=1, $\mathbb{E}[\tau_f]$'+f'={tau1[1].mean():.2f}', alpha=0.7, stat='probability')
sns.histplot(tau2[1], ax=ax, label=r'depth=2, $\mathbb{E}[\tau_f]$'+f'={tau2[1].mean():.2f}', alpha=0.7, stat='probability')
sns.histplot(tau3[1], ax=ax, label=r'depth=3, $\mathbb{E}[\tau_f]$'+f'={tau3[1].mean():.2f}', alpha=0.7, stat='probability')
sns.histplot(tau10[1], ax=ax, label=r'depth=10, $\mathbb{E}[\tau_f]$'+f'={tau10[1].mean():.2f}', alpha=0.7, stat='probability')
ax.legend()
ax.set_title(fr'$\tau_f$, architecture=chain, $D_r$={D_r}')
plt.savefig(f'../data/plots/chain-tau_f-D_r-{D_r}.png', bbox_inches='tight', dpi=300)

# %%
rf3.net.inner[1].register_forward_hook(get_activation('inner.1'))
x = torch.from_numpy(Uo[:, 0])
output = rf3.net(x)
0.4<torch.abs(activation['inner.1'])
# Out:
# tensor([True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True, True, True, True, True, True, True, True, True,
#         True, True, True, True])

# %%
m, s = Uo.mean(axis=1).shape
# Out:
# (3,)

# %%
Uo.std(axis=1).shape
# Out:
# (3,)
