# %%
import os, sys 
from pathlib import Path
from os.path import dirname, realpath
script_dir = Path(dirname(realpath('.')))
module_dir = str(script_dir)
sys.path.insert(0, module_dir + '/modules')
import numpy as np
import utility as ut
import matplotlib.pyplot as plt
import pandas as pd
import warnings
from scipy import stats
import seaborn as sns
import sample as sm
import lstm_forget as arch 
import torch
# warnings.filterwarnings('ignore')

# %%
Uo = np.load('../data/L63-trajectories/train.npy')[:, :20000]
Vo = np.load('../data/L63-trajectories/test.npy')
L0, L1 = 0.4, 3.5
D, D_r, B = 3, 300, 2
beta = 4e-5
m = 500

# %%
B = 1
nn1 = arch.DeepRF(D_r, B, L0, L1, Uo, name='test', save_folder='../data')
tau1 = nn1.compute_tau_f_(Vo[0:m])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 B = 1
# ----> 2 nn1 = arch.DeepRF(D_r, B, L0, L1, Uo, name='test', save_folder='../data')
#       3 tau1 = nn1.compute_tau_f_(Vo[0:m])
#
# File ~/Documents/GitHub/deeprf/modules/lstm_forget.py:83, in DeepRF.__init__(self, D_r, B, L0, L1, Uo, name, save_folder)
#      72 """
#      73 Args:
#      74     D_r: dimension of the feature
#    (...)
#      80     beta: regularization parameter
#      81 """
#      82 super().__init__(D_r, B, L0, L1, Uo, 0., name, save_folder)
# ---> 83 self.net = LSTM(self.sampler.dim, D_r, B)
#
# File ~/Documents/GitHub/deeprf/modules/lstm_forget.py:55, in LSTM.__init__(self, D, D_r, B)
#      53 self.D_r = D_r
#      54 self.B = B
# ---> 55 self.blocks = nn.ModuleList([Forget_Block(self.D, self.D_r) for _ in range(B)])
#      56 self.W = nn.Linear(D, D_r, bias=False)
#
# File ~/Documents/GitHub/deeprf/modules/lstm_forget.py:55, in <listcomp>(.0)
#      53 self.D_r = D_r
#      54 self.B = B
# ---> 55 self.blocks = nn.ModuleList([Forget_Block(self.D, self.D_r) for _ in range(B)])
#      56 self.W = nn.Linear(D, D_r, bias=False)
#
# File ~/Documents/GitHub/deeprf/modules/lstm_forget.py:31, in Forget_Block.__init__(self, D, D_r)
#      30 def __init__(self, D, D_r):
# ---> 31     self.W_f = nn.Linear(D, D_r, bias=True)
#      32     self.U_f = nn.Linear(D, D_r, bias=False)
#      33     self.W_g = nn.Linear(D, D_r, bias=True)
#
# File ~/miniconda3/envs/metal/lib/python3.11/site-packages/torch/nn/modules/module.py:1723, in Module.__setattr__(self, name, value)
#    1721 if isinstance(value, Module):
#    1722     if modules is None:
# -> 1723         raise AttributeError(
#    1724             "cannot assign module before Module.__init__() call")
#    1725     remove_from(self.__dict__, self._parameters, self._buffers, self._non_persistent_buffers_set)
#    1726     for hook in _global_module_registration_hooks.values():
#
# AttributeError: cannot assign module before Module.__init__() call

# %%
B = 2
rf2 = arch.DeepRF(D_r, B, L0, L1, Uo, beta, name='test', save_folder='../data')
rf2.init()
tau2 = rf2.compute_tau_f_(Vo[0:m])
# Out:
# Time taken by sample is 0.0058 seconds
# Time taken by sample is 0.0057 seconds
# Time taken by sample is 0.0135 seconds
# Time taken by sample is 0.0115 seconds
# Time taken by compute_tau_f_ is 23.8150 seconds

# %%
B = 3
rf3 = arch.DeepRF(D_r, B, L0, L1, Uo, beta, name='test', save_folder='../data')
rf3.init()
tau3 = rf3.compute_tau_f_(Vo[0:m])
# Out:
# Time taken by sample is 0.0053 seconds
# Time taken by sample is 0.0078 seconds
# Time taken by sample is 0.0119 seconds
# Time taken by sample is 0.0055 seconds
# Time taken by sample is 0.0107 seconds
# Time taken by sample is 0.0120 seconds
# Time taken by compute_tau_f_ is 34.9571 seconds

# %%
B = 10
rf10 = arch.DeepRF(D_r, B, L0, L1, Uo, beta, name='test', save_folder='../data')
rf10.init()
tau10 = rf10.compute_tau_f_(Vo[0:m])
# Out:
# Time taken by sample is 0.0053 seconds
# Time taken by sample is 0.0077 seconds
# Time taken by sample is 0.0096 seconds
# Time taken by sample is 0.0079 seconds
# Time taken by sample is 0.0064 seconds
# Time taken by sample is 0.0147 seconds
# Time taken by sample is 0.0094 seconds
# Time taken by sample is 0.0139 seconds
# Time taken by sample is 0.0119 seconds
# Time taken by sample is 0.0121 seconds
# Time taken by sample is 0.0123 seconds
# Time taken by sample is 0.0144 seconds
# Time taken by sample is 0.0098 seconds
# Time taken by sample is 0.0119 seconds
# Time taken by sample is 0.0082 seconds
# Time taken by sample is 0.0145 seconds
# Time taken by sample is 0.0101 seconds
# Time taken by sample is 0.0146 seconds
# Time taken by sample is 0.0097 seconds
# Time taken by sample is 0.0184 seconds
# Time taken by compute_tau_f_ is 117.1564 seconds

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
sns.histplot(tau1[1], ax=ax, label=r'depth=1, $\mathbb{E}[\tau_f]$'+f'={tau1[1].mean():.2f}', alpha=0.7, stat='probability')
sns.histplot(tau2[1], ax=ax, label=r'depth=2, $\mathbb{E}[\tau_f]$'+f'={tau2[1].mean():.2f}', alpha=0.7, stat='probability')
sns.histplot(tau3[1], ax=ax, label=r'depth=3, $\mathbb{E}[\tau_f]$'+f'={tau3[1].mean():.2f}', alpha=0.7, stat='probability')
sns.histplot(tau10[1], ax=ax, label=r'depth=10, $\mathbb{E}[\tau_f]$'+f'={tau10[1].mean():.2f}', alpha=0.7, stat='probability')
ax.legend()
ax.set_title(fr'$\tau_f$, architecture=snake, $D_r$={D_r}')
plt.savefig('../data/plots/snake-tau_f.png', bbox_inches='tight', dpi=300)

# %%
Uo.shape
# Out:
# (3, 20000)
