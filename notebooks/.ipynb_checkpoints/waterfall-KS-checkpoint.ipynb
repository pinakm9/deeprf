# %%
import os, sys 
from pathlib import Path
from os.path import dirname, realpath
script_dir = Path(dirname(realpath('.')))
module_dir = str(script_dir)
sys.path.insert(0, module_dir + '/modules')
import numpy as np
import utility as ut
import matplotlib.pyplot as plt
import pandas as pd
import warnings
from scipy import stats
import seaborn as sns
import eulerN as arch 
import torch
from torch import nn

def waterfall(data, filename=None, drf=None, cmap='magma', levels=15, **tau_f_kwargs):
    n, m = data.shape
    x, y = np.linspace(1, n, num=n), np.linspace(1, m, num=m) * tau_f_kwargs['dt'] / tau_f_kwargs['Lyapunov_time']
    if drf is None:
        fig = plt.figure(figsize=(2, 5))
        ax = fig.add_subplot(111)
        origin = 'lower'
        im = ax.contourf(x, y, data.T, levels=levels, cmap=cmap, origin=origin)
        # ax.contour(x, y, data.T, levels=levels, linewidths=0.5, colors='k')
        ax.contour(x, y, data.T, colors='white', origin=origin, linewidths=.01)
        fig.colorbar(im, ax=[ax])
    else:
        fig = plt.figure(figsize=(5, 5))
        ax = fig.add_subplot(121)
        ax1 = fig.add_subplot(122)
        im = ax.contourf(x, y, data.T, levels=levels, cmap=cmap)
        z = drf.multistep_forecast(data[:, 0], m).cpu().numpy()
        print(z.shape)
        ax1.contourf(x, y, z.T, levels=levels, cmap=cmap)
        # ax1.set_ylabel(r'$t/T^{\Lambda_1}$')
        ax1.set_title(r'Forecast')
        fig.colorbar(im, ax=[ax, ax1])
        ax1.set_yticks([])
    ax.set_ylabel(r'$t/T^{\Lambda_1}$')
    ax.set_title(r'Truth')
    if filename is not None:
        plt.savefig(f'../data/plots/{filename}.png', bbox_inches='tight', dpi=300)
    plt.show()

# %%
# Waterfall for best KS model
L0, L1 = 0.4, 3.5
D_r, B = 8192, 1
training_points = 100000
Uo = torch.tensor(np.load(f'../data/KS-trajectories/train{B}.npy'))
Vo = torch.tensor(np.load(f'../data/KS-trajectories/test.npy'))
# beta_data = pd.read_csv(f'../data/KS/EulerN/beta/beta.csv')
# beta = float(beta_data[beta_data['D_r']==D_r]['beta'].iloc[0])
tau_f_kwargs = {'error_threshold' : 0.25, 'dt': 0.25, 'Lyapunov_time': 1/0.094}
# drf_args = [D_r, B, L0, L1, Uo, beta, 'EulerN', f"../data/EulerN/KS/D_r-{D_r}", False]
# drf = arch.DeepRF(*drf_args)
# data = pd.read_csv(f'../data/KS/EulerN/D_r-{D_r}/batch_data.csv')
# best_index = np.argmax(data['tau_f_nmse'])
# model_seed = int(data['model_seed'].to_numpy()[best_index])
# train_index = int(data['train_index'].to_numpy()[best_index])
# test_index = int(data['test_index'].to_numpy()[best_index])
# train = Uo[:, train_index: train_index + training_points]
# drf.learn(train, model_seed)

# %%
# tau = drf.compute_tau_f(Vo[:500, :, :200], **tau_f_kwargs)
# index = np.argmax(tau[0])
trajectory = Uo[:, 20000:20450]
waterfall(trajectory, filename='KS-waterfall', drf=None, cmap='seismic', levels=20, **tau_f_kwargs)

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
sns.histplot(tau[0], ax=ax)
# Out:
# <Axes: ylabel='Count'>

# %%
# Waterfall for best L96 model
L0, L1 = 0.4, 3.5
D_r, B = 8192, 1
training_points = 100000
Uo = torch.tensor(np.load(f'../data/KS-trajectories/train{B}.npy'))
Vo = torch.tensor(np.load(f'../data/KS-trajectories/test.npy'))
# beta_data = pd.read_csv(f'../data/L96/EulerN/beta/beta.csv')
# beta = float(beta_data[beta_data['D_r']==D_r]['beta'].iloc[0])
tau_f_kwargs = {'error_threshold' : 0.25, 'dt': 0.01, 'Lyapunov_time': 0.094}
# drf_args = [D_r, B, L0, L1, Uo, beta, 'EulerN', f"../data/EulerN/L96/D_r-{D_r}", False]
# drf = arch.DeepRF(*drf_args)
# data = pd.read_csv(f'../data/L96/EulerN/D_r-{D_r}/batch_data.csv')
# best_index = np.argmax(data['tau_f_nmse'])
# model_seed = int(data['model_seed'].to_numpy()[best_index])
# train_index = int(data['train_index'].to_numpy()[best_index])
# test_index = int(data['test_index'].to_numpy()[best_index])
# train = Uo[:, train_index: train_index + training_points]
# drf.learn(train, model_seed)

# %%
trajectory = Uo[:, :1000]
# trajectory = Uo[:, train_index: train_index + 300]
waterfall(trajectory, cmap='seismic', levels=20, **tau_f_kwargs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[122], line 3
#       1 trajectory = Uo[:, :1000]
#       2 # trajectory = Uo[:, train_index: train_index + 300]
# ----> 3 waterfall(trajectory, cmap='seismic', levels=20, **tau_f_kwargs)
#
# Cell In[105], line 24, in waterfall(data, filename, drf, cmap, levels, **tau_f_kwargs)
#      22     fig = plt.figure(figsize=(5, 5))
#      23     ax = fig.add_subplot(111)
# ---> 24     im = ax.contourf(x, y, data.T, levels=levels, cmap=cmap)
#      25     fig.colorbar(im, ax=[ax])
#      26 else:
#
# File ~/miniconda3/envs/metal/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/envs/metal/lib/python3.11/site-packages/matplotlib/axes/_axes.py:6528, in Axes.contourf(self, *args, **kwargs)
#    6519 """
#    6520 Plot filled contours.
#    6521
#    (...)
#    6525 %(contour_doc)s
#    6526 """
#    6527 kwargs['filled'] = True
# -> 6528 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6529 self._request_autoscale_view()
#    6530 return contours
#
# File ~/miniconda3/envs/metal/lib/python3.11/site-packages/matplotlib/contour.py:847, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     843 if self.negative_linestyles is None:
#     844     self.negative_linestyles = \
#     845         mpl.rcParams['contour.negative_linestyle']
# --> 847 kwargs = self._process_args(*args, **kwargs)
#     848 self._process_levels()
#     850 self._extend_min = self.extend in ['min', 'both']
#
# File ~/miniconda3/envs/metal/lib/python3.11/site-packages/matplotlib/contour.py:1533, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1530         corner_mask = mpl.rcParams['contour.corner_mask']
#    1531 self._corner_mask = corner_mask
# -> 1533 x, y, z = self._contour_args(args, kwargs)
#    1535 contour_generator = contourpy.contour_generator(
#    1536     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1537     line_type=contourpy.LineType.SeparateCode,
#    1538     fill_type=contourpy.FillType.OuterCode,
#    1539     chunk_size=self.nchunk)
#    1541 t = self.get_transform()
#
# File ~/miniconda3/envs/metal/lib/python3.11/site-packages/matplotlib/contour.py:1573, in QuadContourSet._contour_args(self, args, kwargs)
#    1571 elif 2 < nargs <= 4:
#    1572     x, y, z_orig, *args = args
# -> 1573     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1575 else:
#    1576     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File ~/miniconda3/envs/metal/lib/python3.11/site-packages/matplotlib/contour.py:1601, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1599     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1600 if z.shape[0] < 2 or z.shape[1] < 2:
# -> 1601     raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1602                     f"but has shape {z.shape}")
#    1603 Ny, Nx = z.shape
#    1605 if x.ndim != y.ndim:
#
# TypeError: Input z must be at least a (2, 2) shaped array, but has shape (0, 512)

# %%
Uo[:, 100000:100450].shape
# Out:
# torch.Size([512, 0])

# %%
1/0.094
# Out:
# 10.638297872340425
